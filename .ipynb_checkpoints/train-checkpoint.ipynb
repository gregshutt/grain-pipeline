# %%
# !pip install -r requirements-train.txt
# !python -m open_clip_train.main --workers 1 --train-data 'samples-00.tar' --train-num-samples 1  --dataset-type webdataset
# Out:
# ...
# 2026-03-20,00:14:41 | INFO | Running with a single process. Device cuda.
# 2026-03-20,00:14:41 | INFO | Parsing model identifier. Schema: None, Identifier: RN50
# 2026-03-20,00:14:41 | INFO | Loaded built-in RN50 model config.
# 2026-03-20,00:14:41 | INFO | No potential checkpoint path found from config source or pretrained arg.
# 2026-03-20,00:14:41 | INFO | Instantiating model architecture: CLIP
# /opt/app-root/lib64/python3.12/site-packages/torch/cuda/__init__.py:789: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2026-03-20,00:14:41 | WARNING | No pretrained weights loaded for model 'RN50'. Model initialized randomly.
# 2026-03-20,00:14:41 | INFO | Final image preprocessing configuration set: {'size': 224, 'mode': 'RGB', 'mean': (0.48145466, 0.4578275, 0.40821073), 'std': (0.26862954, 0.26130258, 0.27577711), 'interpolation': 'bicubic', 'resize_mode': 'shortest', 'fill_color': 0}
# ...
