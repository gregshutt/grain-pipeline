# %%
# !pip install -r requirements-process.txt

import torchvision.transforms as transforms
from PIL import Image
from minio import Minio
import webdataset as wds
import io
import os

client = Minio(
    os.environ.get('AWS_S3_ENDPOINT'), 
    access_key = os.environ.get('AWS_ACCESS_KEY_ID'), 
    secret_key = os.environ.get('AWS_SECRET_ACCESS_KEY'),
    cert_check = False
)
bucket_name = os.environ.get('AWS_S3_BUCKET')

preproc = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

def download_image(client, object_name):
    try:
        response = client.get_object(bucket_name, object_name)
        image_data = response.read(decode_content=True)
    finally:
        if response:
            response.close()
            response.release_conn()
    return(Image.open(io.BytesIO(image_data)))

def preprocess(image):
    return preproc(image)

def upload_shard(filename):
    print(filename)

objects = client.list_objects(bucket_name=bucket_name, 
                              prefix="dataset/")
# look into post argument to call a func
sink = wds.ShardWriter("samples-%02d.tar")

index = 0
for obj in objects:
    image_data = download_image(client, obj.object_name)
    processed_image = transforms.ToPILImage()(preprocess(image_data))
    image_byte_array = io.BytesIO()
    processed_image.save(image_byte_array, format='PNG')
    image_byte_array = image_byte_array.getvalue()
    sample = {
        "__key__": "sample%06d" % index,
        "image.png": image_byte_array,
        "notes.txt": "abc".encode()
    }
    sink.write(sample)
    index += 1
sink.close()
# Out:
# Requirement already satisfied: minio in /opt/app-root/lib64/python3.12/site-packages (from -r requirements-process.txt (line 1)) (7.2.20)
# Requirement already satisfied: webdataset in /opt/app-root/lib64/python3.12/site-packages (from -r requirements-process.txt (line 2)) (0.2.86)
# Requirement already satisfied: argon2-cffi in /opt/app-root/lib64/python3.12/site-packages (from minio->-r requirements-process.txt (line 1)) (25.1.0)
# Requirement already satisfied: certifi in /opt/app-root/lib64/python3.12/site-packages (from minio->-r requirements-process.txt (line 1)) (2026.1.4)
# Requirement already satisfied: pycryptodome in /opt/app-root/lib64/python3.12/site-packages (from minio->-r requirements-process.txt (line 1)) (3.23.0)
# Requirement already satisfied: typing-extensions in /opt/app-root/lib64/python3.12/site-packages (from minio->-r requirements-process.txt (line 1)) (4.15.0)
# Requirement already satisfied: urllib3 in /opt/app-root/lib64/python3.12/site-packages (from minio->-r requirements-process.txt (line 1)) (2.6.3)
# Requirement already satisfied: braceexpand in /opt/app-root/lib64/python3.12/site-packages (from webdataset->-r requirements-process.txt (line 2)) (0.1.7)
# Requirement already satisfied: numpy in /opt/app-root/lib64/python3.12/site-packages (from webdataset->-r requirements-process.txt (line 2)) (2.3.5)
# Requirement already satisfied: pyyaml in /opt/app-root/lib64/python3.12/site-packages (from webdataset->-r requirements-process.txt (line 2)) (6.0.3)
# Requirement already satisfied: argon2-cffi-bindings in /opt/app-root/lib64/python3.12/site-packages (from argon2-cffi->minio->-r requirements-process.txt (line 1)) (25.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/app-root/lib64/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi->minio->-r requirements-process.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /opt/app-root/lib64/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->-r requirements-process.txt (line 1)) (2.23)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 38
#      34     return preproc(image)
#      36 objects = client.list_objects(bucket_name=bucket_name,
#      37                               prefix="dataset/")
# ---> 38 sink = wds.ShardWriter("dest.tar")
#      40 index = 0
#      41 for obj in objects:
#
# File /opt/app-root/lib64/python3.12/site-packages/webdataset/writer.py:539, in __init__(self, pattern, maxcount, maxsize, post, start_shard, verbose, opener, **kw)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/app-root/lib64/python3.12/site-packages/webdataset/writer.py:544, in next_stream(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# TypeError: not all arguments converted during string formatting
